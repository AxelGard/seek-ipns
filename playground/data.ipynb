# %%
import pandas as pd 
import requests

r = requests.get("http://127.0.0.1:5000/api/model/score")
assert r.status_code == 200
data = r.json()

df = pd.DataFrame(data)
df.plot()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >
