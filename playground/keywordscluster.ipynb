# %% [markdown]
# # Information extraction using tf-idf

# %%
import pandas as pd 
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# loading in readme file and making them in to tokens

# %%
from os import listdir
from os.path import isfile, join

contents = []
PATH = "../data"
files = [f"{PATH}/{f}" for f in listdir(PATH) if isfile(join(PATH, f))]

for file_path in files: 
    with open(file_path, "r") as f:
        contents.append(f.read())

contents[0][:50]
# Out:
# '[![Cybernetically enhanced web apps: Svelte](https'

# %%
def load_stop_words(path:str="../stopwords.txt"):
   words = []
   with open(path, "r") as f: 
      words = f.read().split("\n")
   assert len(words) != 0, "no stop words were found"
   return words

# %%
import nltk
def clean(content:list):
    ascii_char = [chr(i) for i in range(0,255)]
    numbers = "0123456789"
    non_acc_char =  "\n,.()[]{}`/:-_*=\\<>|&%@?!\"\'#" + numbers
    non_acc_tokens = ["https","www", "com", "org", "license"]
    stop_words = load_stop_words()
    for i, _ in enumerate(content):
        for c in non_acc_char:
            content[i] = content[i].replace(c, " ")
        content[i] = content[i].split(" ")
        content[i] = list(filter(lambda c: c != "", content[i]))
        content[i] = [t for t in content[i] if not t in non_acc_tokens ] 
        content[i] = [s.lower() for s in content[i] if all(c in ascii_char for c in s)]
        content[i] = [t for t in content[i] if not t in stop_words] 
        ps = nltk.stem.PorterStemmer()
        content[i] = [ps.stem(t) for t in content[i]] 


    return [" ".join(con) for con in content]


contents = clean(contents)
contents
# Out:
# ['cybernet enhanc app svelt sveltej github asset banner png svelt dev npm version img shield npm svelt svg npmj packag svelt img shield npm svelt svg licens chat img shield discord label chat logo discord svelt dev chat svelt svelt build applic compil take declar compon convert effici javascript surgic updat dom learn svelt svelt dev discord chatroom svelt dev chat support svelt svelt mit licens sourc project ongo develop fantast volunt support effort backer collect opencollect svelt fund donat collect compens expens svelt develop host cost suffici donat receiv fund support svelt develop roadmap view roadmap svelt dev roadmap develop pull request encourag pick issu github sveltej svelt issu aissue+i aopen+sort aupdat desc instal svelt local bash git clone github sveltej svelt git svelt npm instal yarn instal depend specif packag version packag lock json build svelt build compil modul includ packag bash npm build watch continu rebuild packag npm link doc npmj cli link project local bash npm dev compil written typescript typescriptlang basic javascript type annot pick time editor visual studio code code visualstudio instal plugin syntax highlight code hint run test bash npm filter test aka grep test involv transit bash npm transit svelt dev sourc code svelt dev live site github sveltej site repositori document content content directori built sveltekit kit svelt dev svelt dev access dev site check superus question answer superus licens mit licens',
#  'div align center img src tensorflow imag logo horizont png div python img shield pypi pyvers tensorflow svg style plastic badg furi tensorflow pypi badg furi tensorflow svg badg furi tensorflow doi zenodo badg doi zenodo svg doi zenodo cii practic bestpractic coreinfrastructur project badg bestpractic coreinfrastructur project openssf scorecard api securityscorecard dev project github tensorflow tensorflow badg api securityscorecard dev project github tensorflow tensorflow fuzz statu oss fuzz build log storag googleapi badg tensorflow svg bug chromium oss fuzz issu list sort proj tensorflow fuzz statu oss fuzz build log storag googleapi badg tensorflow svg bug chromium oss fuzz issu list sort proj tensorflow ossrank shield endpoint url ossrank shield ossrank contributor coven img shield badg contributor coven svg code conduct document document img shield badg api refer blue svg tensorflow api doc tensorflow tensorflow sourc platform machin learn comprehens flexibl ecosystem tool tensorflow resourc tool librari tensorflow resourc librari extens commun tensorflow commun resourc research push art develop easili build deploy power applic tensorflow origin develop research engin googl brain team googl machin intellig organ conduct machin learn deep neural network applic wide varieti domain tensorflow stabl python tensorflow api doc python c++ tensorflow api doc api guarante compat api languag tensorflow api doc releas announc secur updat subscrib tensorflow googl tensorflow forum forum mail list tensorflow commun forum instal tensorflow instal guid tensorflow instal pip packag tensorflow instal pip enabl gpu support tensorflow instal gpu docker contain tensorflow instal docker build sourc tensorflow instal sourc instal current releas includ support cuda enabl gpu card tensorflow instal gpu ubuntu window $ pip instal tensorflow devic directx maco metal support devic plugin tensorflow instal gpu plugin devic cpu packag $ pip instal tensorflow cpu updat tensorflow version add upgrad flag command nightli binari test nightli pypi python pypi nightli nightli cpu pypi python pypi nightli cpu packag pypi tensorflow program $ python python import tensorflow add numpi constant tensorflow numpi tensorflow exampl tensorflow tutori tensorflow tutori contribut guidelin contribut tensorflow review contribut guidelin contribut project adher tensorflow code conduct code conduct particip expect uphold code github issu github tensorflow tensorflow issu track request bug tensorflow forum discuss tensorflow question discuss direct specif question stack overflow stackoverflow question tag tensorflow tensorflow project strive abid accept practic sourc softwar develop patch guidelin follow step patch specif version tensorflow appli fix bug secur vulner clone tensorflow repo switch branch desir tensorflow version branch version appli cherri pick desir resolv code conflict tensorflow test ensur pass build tensorflow instal sourc tensorflow pip packag sourc continu build statu commun support platform configur tensorflow sig build commun build tabl github tensorflow build commun support tensorflow build offici build build type statu artifact linux cpu statu storag googleapi tensorflow kokoro build badg ubuntu svg storag googleapi tensorflow kokoro build badg ubuntu pypi pypi project nightli linux gpu statu storag googleapi tensorflow kokoro build badg ubuntu gpu svg storag googleapi tensorflow kokoro build badg ubuntu gpu pypi pypi project nightli gpu linux xla statu storag googleapi tensorflow kokoro build badg ubuntu xla svg storag googleapi tensorflow kokoro build badg ubuntu xla tba maco statu storag googleapi tensorflow kokoro build badg maco svg storag googleapi tensorflow kokoro build badg maco pypi pypi project nightli window cpu statu storag googleapi tensorflow kokoro build badg window cpu svg storag googleapi tensorflow kokoro build badg window cpu pypi pypi project nightli window gpu statu storag googleapi tensorflow kokoro build badg window gpu ...
#  'react reactj middot; github img shield badg mit blue svg github facebook react blob main licens npm version img shield npm react svg style flat npmj packag react circleci statu circleci facebook react svg style shield circleci facebook react pr img shield badg pr brightgreen svg reactj doc contribut pull request react javascript librari build user interfac declar react painless creat interact ui design simpl view applic react effici updat render compon data declar view code predict simpler understand easier debug compon base build encapsul compon manag compos complex ui compon logic written javascript templat easili pass rich data app dom learn write assumpt rest technolog stack develop featur react rewrit exist code react render server node power mobil app react nativ reactn dev learn react project reactj doc start instal react design gradual adopt start react onlin playground reactj doc start onlin playground tast react add react reactj doc add react script tag minut creat react app reactj doc creat react app power javascript toolchain react script tag cdn reactj doc cdn link react packag npm npmj packag react document react document reactj check start reactj doc start quick overview document divid section tutori reactj tutori tutori main concept reactj doc advanc guid reactj doc jsx depth api refer reactj doc react api support reactj commun support contribut guid reactj doc contribut improv send pull request repositori github reactj reactj exampl exampl reactj start jsx import createroot react dom client ; function hellomessag return div div ; const root createroot document getelementbyid contain ; root render hellomessag taylor ; render taylor contain notic syntax; jsx reactj doc introduc jsx jsx requir react code readabl write feel write react script tag read reactj doc add react option react jsx integr jsx; recommend javascript toolchain reactj doc creat react app handl automat contribut main purpos repositori continu evolv react core faster easier develop react github grate commun contribut bugfix improv read learn improv react code conduct code fb codeofconduct facebook code conduct expect project particip adher read code fb codeofconduct understand action toler contribut guid reactj doc contribut read contribut guid reactj doc contribut learn develop process propos bugfix improv build react issu feet wet familiar contribut process list issu github facebook react label issu bug limit scope start licens react mit licens licens',
#  'align center href vuej target blank rel noopen noreferr img src vuej imag logo png alt vue logo align center href circleci vuej vue tree dev img src img shield circleci project github vuej vue dev svg sanit true alt build statu href codecov github vuej vue branch dev img src img shield codecov github vuej vue dev svg sanit true alt coverag statu href npmchart compar vue minim true img src img shield npm vue svg sanit true alt download href npmj packag vue img src img shield npm vue svg sanit true alt version href npmj packag vue img src img shield npm vue svg sanit true alt licens href chat vuej img src img shield badg chat discord da svg sanit true alt chat repo vue repositori vue repo vue vuej core github vuej core sponsor vue js mit licens sourc project ongo develop support awesom backer github vuej core blob main backer sponsor vue develop vuej sponsor align center align center special sponsor align center target blank href github appwrit appwrit img alt special sponsor appwrit src sponsor vuej imag appwrit svg align center target blank href vuej sponsor img alt sponsor src sponsor vuej sponsor svg introduct vue pronounc view progress framework build user interfac design ground increment adopt easili scale librari framework depend consist approach core librari focus view layer ecosystem support librari help tackl complex singl applic browser compat vue js support browser compliant kangax github compat tabl support ecosystem project statu descript vue router vue router statu vue router packag singl applic rout vuex vuex statu vuex packag scale manag vue cli vue cli statu vue cli packag project scaffold vue loader vue loader statu vue loader packag singl file compon vue file loader webpack vue server render vue server render statu vue server render packag server render support vue class compon vue class compon statu vue class compon packag typescript decor class base api vue rx vue rx statu vue rx packag rxj integr vue devtool vue devtool statu vue devtool packag browser devtool extens vue router github vuej vue router vuex github vuej vuex vue cli github vuej vue cli vue loader github vuej vue loader vue server render github vuej vue tree dev packag vue server render vue class compon github vuej vue class compon vue rx github vuej vue rx vue devtool github vuej vue devtool vue router statu img shield npm vue router svg vuex statu img shield npm vuex svg vue cli statu img shield npm vue cli svg vue loader statu img shield npm vue loader svg vue server render statu img shield npm vue server render svg vue class compon statu img shield npm vue class compon svg vue rx statu img shield npm vue rx svg vue devtool statu img shield chrome store nhdogjmejiglipccpnnnanhbledajbpd svg vue router packag npmj packag vue router vuex packag npmj packag vuex vue cli packag npmj packag vue cli vue loader packag npmj packag vue loader vue server render packag npmj packag vue server render vue class compon packag npmj packag vue class compon vue rx packag npmj packag vue rx vue devtool packag chrome googl webstor vuej devtool nhdogjmejiglipccpnnnanhbledajbpd document check live exampl vuej exampl doc visit vuej vuej question question support offici forum forum vuej commun chat chat vuej issu list repo exclus bug report featur request issu read issu report checklist github vuej vue blob dev github contribut issu report guidelin issu issu conform guidelin close changelog detail releas document releas note github vuej vue releas stay touch twitter twitter vuej blog medium vue job board vuejob vuej contribut read contribut guid github vuej vue blob dev github contribut pull request vue project compon tool add pull request curat list github vuej awesom vue peopl contribut vue href github vuej vue graph contributor img src opencollect vuej contributor svg licens mit opensourc licens mit copyright yuxi evan',
#  'directori gnu compil collect gcc gnu compil collect softwar file name start copi copi permiss manual runtim librari terms; individu sourc file detail directori instal copi instal plain sourc gcc doc instal texi instal includ detail includ gcc sourc file gcc instal file gcc doc gcc texi file includ usag port onlin readabl version manual file gcc doc gcc info gcc gnu bug report bug copyright gcc sourc file list rang notat indic rang inclus copyright list individu',
#  'linux kernel guid kernel develop user guid render format pdf read document admin guid readm rst build document htmldoc pdfdoc format document read onlin kernel doc file document subdirectori restructur markup notat read document process rst file requir build run kernel result upgrad kernel',
#  'python version alpha imag github python cpython workflow test badg svg alt cpython build statu github action target github python cpython action imag dev azur python cpython api build statu azur pipelin branchnam main alt cpython build statu azur devop target dev azur python cpython build definitionid branchnam main imag img shield badg discours chat brightgreen svg alt python discours chat target discuss python copyright © python softwar foundat right file copyright content python sourc code github python cpython issu tracker github python cpython issu document doc python develop guid devguid python contribut cpython complet instruct contribut cpython develop develop guid develop guid devguid python python instal python kit python python python python build instruct unix linux bsd maco cygwin configur sudo instal instal python python pass option configur script; configur maco insensit file system cygwin execut call python exe ; python build complet python instal requir addit parti librari depend build platform configur option standard librari modul buildabl useabl platform refer instal depend devguid python start setup build build depend develop guid current detail depend linux distribut maco maco addit configur build option maco framework univers build refer mac readm rst github python cpython blob main mac readm rst window pcbuild readm txt github python cpython blob main pcbuild readm txt creat subdirectori invok configur mkdir debug debug configur pydebug fail built level directori clean level optim build python configur enabl optim set default target enabl profil guid optim pgo auto enabl link time optim lto platform detail section profil guid optim ^^^^^^^^^^^^^^^^^^^^^^^^^^^ pgo take advantag version gcc clang compil configur enabl optim manual run profil opt configur flag optim build process perform step entir python directori clean temporari file previou compil instrument version interpret built suitabl compil flag flavor note intermediari step binari step real life workload profil instruct embed instrument interpret built makefil train workload profil interpret execut note output stdout stderr step suppress final step build actual interpret collect instrument result python binari optimized; suitabl distribut product instal link time optim ^^^^^^^^^^^^^^^^^^^^^^ enabl configur lto flag lto take advantag abil compil toolchain optim arbitrari file boundari build final execut share librari addit perform gain comprehens overview python doc python whatsnew document detail chang log read misc news github python cpython tree main misc news account glean commit histori github python cpython commit main instal multipl version python entitl instal multipl version document document python doc python onlin updat daili download format faster access document download pdf restructuredtext formats; version document author translat peopl special format requir build python document refer doc readm rst github python cpython blob main doc readm rst convert python incompat releas python program written python fail python port code python python port howto doc python howto pyport test interpret type level directori set produc output ignor messag skip test option featur import messag print fail traceback core dump produc wrong default test prevent overus resourc disk space memori enabl test testal test fail fail verbos mode os gdb fail testopt os gdb failur persist appear python environ file bug report github python cpython issu includ relev output command issu run write test devguid python test write test run test instal multipl version unix mac system intend instal multipl version python instal prefix prefix argument configur script care primari python execut overwritten instal version file directori instal altinstal major minor version live instal creat $ prefix bin python refer $ prefix bin python intend instal multipl version prefix decid version primari version instal version instal instal version altinstal instal python primari ve ...
#  'pytorch logo github pytorch pytorch blob main doc sourc static img pytorch logo dark png pytorch python packag level featur tensor comput numpi strong gpu acceler deep neural network built tape base autograd reus favorit python packag numpi scipi cython extend pytorch trunk health continu integr signal hud pytorch hud pytorch pytorch pytorch main toc pytorch pytorch gpu readi tensor librari gpu readi tensor librari dynam neural network tape base autograd dynam neural network tape base autograd python python imper experi imper experi fast lean fast lean extens pain extens pain instal instal binari binari nvidia jetson platform nvidia jetson platform sourc sourc prerequisit prerequisit instal depend instal depend pytorch sourc pytorch sourc instal pytorch instal pytorch adjust build option option adjust build option option docker imag docker imag pre built imag pre built imag build imag build imag build document build document previou version previou version start start resourc resourc commun commun releas contribut releas contribut team team licens tocstop pytorch granular level pytorch librari consist compon compon descript torch pytorch doc stabl torch tensor librari numpi strong gpu support torch autograd pytorch doc stabl autograd tape base automat differenti librari support differenti tensor oper torch torch jit pytorch doc stabl jit compil stack torchscript creat serializ optimiz model pytorch code torch nn pytorch doc stabl nn neural network librari deepli integr autograd design maximum flexibl torch multiprocess pytorch doc stabl multiprocess python multiprocess magic memori share torch tensor process data load hogwild train torch util pytorch doc stabl data dataload util function conveni pytorch replac numpi power gpu deep learn platform maximum flexibl speed elabor gpu readi tensor librari numpi tensor ndarray tensor illustr doc sourc static img tensor illustr png pytorch tensor live cpu gpu acceler comput huge provid wide varieti tensor routin acceler fit scientif comput slice index mathemat oper linear algebra reduct fast dynam neural network tape base autograd pytorch uniqu build neural network replay tape record framework tensorflow theano caff cntk static view build neural network reus structur chang network behav start scratch pytorch techniqu call revers mode auto differenti chang network behav arbitrarili lag overhead inspir paper topic current torch autograd github twitter torch autograd autograd github hip autograd chainer chainer techniqu uniqu pytorch fastest implement speed flexibl crazi dynam graph github pytorch pytorch blob main doc sourc static img dynam graph gif python pytorch python bind monolith c++ framework built deepli integr python natur numpi numpi scipi scipi scikit learn scikit learn write neural network layer python favorit librari packag cython cython numba numba pydata goal reinvent wheel imper experi pytorch design intuit linear easi execut code execut asynchron view drop debugg receiv error messag stack trace understand straightforward stack trace code defin hope spend hour debug code bad stack trace asynchron opaqu execut engin fast lean pytorch minim framework overhead integr acceler librari intel mkl softwar intel mkl nvidia cudnn develop nvidia cudnn nccl develop nvidia nccl maxim speed core cpu gpu tensor neural network backend matur test pytorch fast neural network memori usag pytorch extrem effici compar torch altern written custom memori alloc gpu deep learn model maxim memori effici enabl train bigger deep learn model extens pain write neural network modul interfac pytorch tensor api design straightforward minim abstract write neural network layer python torch api favorit numpi base librari scipi pytorch tutori advanc numpi extens tutori write layer c++ provid conveni extens api effici minim boilerpl wrapper code written tutori pytorch tutori advanc cpp extens github pytorch extens cpp instal binari command instal binari conda pip wheel pytorch start local pytorch start loca ...
#  'rust program languag rust commun img shield badg rust commun brightgreen style plastic logo rust rust lang commun main sourc code repositori rust compil standard librari document rust rust lang note readm user contributor contribut compil read contribut contribut quick start read instal book instal doc rust lang book instal book doc rust lang book instal sourc rust build python script call build compil manag bootstrap process live root project file name config toml determin configur set build list option config toml command unix system format subcommand flag document exampl assum run altern unix python command subcommand flag window command prompt file configur python subcommand flag python python subcommand flag run flag read rustc dev guid rustcguidebuild gettingstart rustc dev guid rust lang start rustcguidebuild rustc dev guid rust lang build build depend instal depend python git compil build host enough; cross compil addit compil curl window pkg config compil linux target linux libiconv includ glibc debian base distro build cargo openssl libssl dev openssl devel unix distro build llvm sourc addit tool g++ clang++ msvc version list llvm document llvm doc gettingstart host toolchain compil standard librari ninja gnu ninja recommend window cmake libstdc++ static requir linux distribut fedora ubuntu tier tier host tool platform choos download llvm set llvm download llvm true llvm instal llvm config path rustc dev guid info sysllvm sysllvm rustc dev guid rust lang build target pre built llvm build unix build step clone sourc git git clone github rust lang rust git rust sourc github rust lang rust configur build set configur plan instal creat instal recommend set prefix instal directori configur set instal prefix path build instal build instal complet instal program $prefix bin rustc rust compil rustdoc api document tool default includ cargo rust packag manag disabl behavior pass set build extend fals configur cargo github rust lang cargo configur project configur script makefil invok configur recommend programat gener config toml recommend support break unnecessarili configur sudo instal configur gener config toml normal invoc build window window winget instal depend run termin powershel winget instal python python winget instal kitwar cmake winget instal git git edit path variabl add program file cmake bin guid edit path java en download path java document winget github winget cli promin abi window nativ msvc abi visual studio gnu abi gcc toolchain version rust depend c++ librari interoper msvc build rust interop softwar produc visual studio gnu build interop gnu softwar built mingw msi toolchain mingw msi msi easili build rust window msi msi download msi instal msi instal mingw bat mingw bat msi instal directori msi depend bit bit rust version msi msi cmd mingw msi cmd mingw command termin instal requir tool updat packag mirror fresh instal msi pacman pacman mirror instal build tool rust build bit compil replac git python cmake instal path remov list note python cmake ninja packag msi subsystem build histor fail packag pacman git diffutil tar mingw python mingw cmake mingw gcc mingw ninja navig rust sourc code clone build python setup user python build python instal msvc msvc build rust addit requir instal visual studio rustc linker simplest visual studio check c++ build tool window sdk workload visual studio visualstudio download instal cmake care c++ cmake tool window includ individu compon depend instal build compil cmd exe python setup user python build build rust version visual studio version instal build understand forc rustbuild version manual call vcvar file run bootstrap batch program file visual studio commun auxiliari build vcvar bat python build abi specif abi environ gnu abi powershel explicit build tripl window build tripl gnu abi gcc pc window gnu pc window gnu msvc abi pc window msvc pc window msvc build tripl build tripl invok command creat config toml file build unix build unix pass set build build tripl  ...
#  'cira cira algorithm trade easi façad librari refactor guru design pattern facad simpler interact alpaca trade api alpaca market cira pip pypi project cira star cira extern content duckduckgo iu pinimg fb fb cfea fcfeceeb fa ced llama draw draw art jpg nofb github star img shield github star axelgard cira style social github fork img shield github fork axelgard cira style social tweet img shield twitter url shield svg style social twitter axel gard github img shield github axelgard cira style plastic pypi img shield pypi cira pypi python version img shield pypi pyvers cira pypi download img shield pypi cira cira spell word babi alpaca cria en wikipedia wiki cria simpl lib perfect fit axel gard github axelgard main develop cira start start fast cira boilerpl github cira cira boilerpl cira checkout tutori github axelgard cira wiki tutori instal instal pip pypi project cira bash pip instal cira usag alpaca trade api api key gener key alpaca market app alpaca market signup play paper trade recommend beginn recommend json file cira path set variabl environ variabl wiki github axelgard cira wiki store alpaca api key diffrent recommend store file upload file public repositori key json json apca api key pub key apca api secret key privat key start lib python import cira cira alpaca key file mypath key json stock cira stock tsla stock stock sell class cira python portfolio cira portfolio method portfolio exchang cira exchang method exchang stock cira stock tsla class stock simpl algorithm coupl line run super simpl algorithm python import cira import random import time cira alpaca key file mypath key json portfolio cira portfolio exchang cira exchang qti choos stock handl session true exchang stock random choic exchang stock qti stock stock random choic portfolio own stock qti stock sell time sleep min timer exampl wiki exampl github axelgard cira wiki exampl wiki tutori github axelgard cira wiki tutori checkout news github axelgard cira discuss categori news wiki github axelgard cira wiki tutori github axelgard cira wiki tutori store alpaca api key github axelgard cira wiki store alpaca api key exampl cira github axelgard cira wiki exampl discuss github axelgard cira discuss cira github cira wiki github axelgard cira wiki doc check wiki github axelgard cira wiki build fund trader cira github axelgard cira wiki exampl simpl fund version compat fork cira cira classic github axelgard cira classic cira classic pypi pip pypi project cira classic bug plz issu solv pull request question question cira share built cira talk cira checkout discuss github axelgard cira discuss issu fit histori cira alpaca trade api build quantit paper trader project github axelgard paper trader alomst realiz alomst build librari alpaca api real librari start quantit paper trade develop develop cira feel pull request issu instal cira dev req bash git clone git github axelgard cira git cira git checkout develop bash python venv env sourc env bin activ pip instal test pytest ensur cira dir key key test mind asset portfolio sold bash touch test key json pytest code style follow pep pep standard notat librari intuit easi licens project licens mit licens licens licens txt file detail acknowledg alpaca api alpaca market paper trader github axelgard paper trader cira classic github axelgard cira classic']

# %%
def TfIdf(content:list):
    vectorizer = TfidfVectorizer()
    vecs = vectorizer.fit_transform(content)
    feature_names = vectorizer.get_feature_names_out()
    dense = vecs.todense()
    dense_list = dense.tolist()
    df = pd.DataFrame(dense_list, columns=feature_names)
    return df

tf_idf_data = TfIdf(contents)

# %%
from collections import defaultdict

def query_data(tf_idf_data:dict, query:str)->list:
    query = clean([query])[0]
    print(query.split(" "))
    words_tf_idf = {}
    query_words = query.split(" ")
    for word in query_words: 
        if word in tf_idf_data.keys():
            words_tf_idf[word] = tf_idf_data[word]

    result = []
    highest = 0.0
    for word, tf_idf in words_tf_idf.items():
        for idx, val in tf_idf.items(): 
            if val > highest: 
                highest = val 
                result.append((val, idx))
    result.sort()
    result.reverse()
    lookup = set()
    result = [idx for _, idx in result if idx not in lookup and lookup.add(idx) is None]
    return result

# %%
query = "compilers"
idxs = query_data(tf_idf_data.to_dict(), query)
for idx in idxs:    
    print(files[idx])
# Out:
# ['compil']
# ../data/rust_README.md
# ../data/gcc_README.txt
# ../data/svelte_README.md

# %%
tf_idf_data.to_dict().keys()
# Out:
# dict_keys(['abi', 'abid', 'abil', 'abstract', 'acceler', 'accept', 'access', 'account', 'acknowledg', 'action', 'activ', 'actual', 'adam', 'add', 'addit', 'adher', 'adjust', 'admin', 'adopt', 'advanc', 'advantag', 'agvnhpsajp', 'agx', 'aissue', 'aka', 'alban', 'algebra', 'algorithm', 'align', 'alloc', 'alomst', 'alpaca', 'alpha', 'alt', 'altern', 'altinstal', 'alykhan', 'amd', 'anaconda', 'andrea', 'android', 'annot', 'announc', 'answer', 'antiga', 'aopen', 'apach', 'apca', 'api', 'app', 'appear', 'appli', 'applic', 'approach', 'appwrit', 'arbitrari', 'arbitrarili', 'argument', 'armv', 'art', 'artifact', 'asset', 'assum', 'assumpt', 'asynchron', 'audienc', 'aupdat', 'author', 'auto', 'autograd', 'automat', 'auxiliari', 'available', 'awar', 'awesom', 'ax', 'axel', 'axelgard', 'azur', 'babi', 'backend', 'backer', 'bad', 'badg', 'banner', 'base', 'bash', 'basic', 'bat', 'batch', 'beginn', 'behav', 'behavior', 'beopen', 'bestpractic', 'bib', 'bigger', 'bin', 'binari', 'bind', 'bintray', 'bit', 'bla', 'blank', 'blob', 'block', 'blog', 'blue', 'board', 'boilerpl', 'book', 'bootstrap', 'boundari', 'bradburi', 'brain', 'branch', 'branchnam', 'brand', 'break', 'brightgreen', 'browser', 'bsd', 'bug', 'bugfix', 'build', 'buildabl', 'buildtool', 'built', 'caff', 'call', 'card', 'care', 'cargo', 'cat', 'catalog', 'categori', 'caus', 'cbg', 'ccmake', 'cdn', 'ced', 'center', 'centrum', 'certif', 'cfea', 'chainer', 'chanan', 'chang', 'changelog', 'channel', 'chat', 'chatroom', 'check', 'checkbox', 'checklist', 'checkout', 'cherri', 'chilamkurthi', 'chintala', 'choic', 'choos', 'christian', 'chrome', 'chromium', 'cii', 'cira', 'circleci', 'clang', 'class', 'classic', 'clean', 'cli', 'client', 'clone', 'close', 'cmake', 'cmd', 'cntk', 'code', 'codecov', 'codelab', 'codeofconduct', 'collabor', 'collect', 'combin', 'come', 'command', 'commit', 'common', 'commun', 'comp', 'compar', 'compat', 'compens', 'compil', 'complet', 'complex', 'compliant', 'compon', 'compos', 'comprehens', 'comput', 'concept', 'conda', 'condit', 'conduct', 'config', 'configur', 'conflict', 'conform', 'connect', 'consist', 'const', 'constant', 'contain', 'content', 'continu', 'contribut', 'contributor', 'control', 'conveni', 'convert', 'copi', 'copyright', 'core', 'coreinfrastructur', 'corpor', 'correct', 'cost', 'coupl', 'cours', 'coursera', 'coven', 'cover', 'coverag', 'cp', 'cpp', 'cpu', 'cpython', 'crazi', 'creat', 'createroot', 'cria', 'cross', 'crunch', 'csrc', 'cuda', 'cudahostcxx', 'cudnn', 'curat', 'curl', 'current', 'custom', 'cxx', 'cybernet', 'cycl', 'cygwin', 'cython', 'da', 'daili', 'dark', 'data', 'dataload', 'day', 'debian', 'debug', 'debugg', 'decid', 'declar', 'decor', 'deep', 'deeplearn', 'deepli', 'default', 'defin', 'definitionid', 'depend', 'deploy', 'depth', 'desc', 'descript', 'design', 'desir', 'desmaison', 'detail', 'detect', 'determin', 'dev', 'devel', 'develop', 'devguid', 'devic', 'devito', 'devop', 'devtalk', 'devtool', 'differenti', 'diffrent', 'diffutil', 'dir', 'direct', 'directori', 'directx', 'dirnam', 'disabl', 'disclaim', 'discord', 'discours', 'discuss', 'disk', 'distribut', 'distro', 'distutil', 'div', 'divid', 'dmytro', 'dnnl', 'doc', 'docker', 'dockerfil', 'document', 'doi', 'dom', 'domain', 'donat', 'download', 'draw', 'driven', 'driver', 'drop', 'duckduckgo', 'dukhan', 'dump', 'dusti', 'dynam', 'dzhulgakov', 'earlier', 'easi', 'easier', 'easili', 'ecosystem', 'edit', 'editor', 'edward', 'edx', 'eepurl', 'effici', 'effort', 'elabor', 'email', 'embed', 'en', 'enabl', 'encapsul', 'encount', 'encourag', 'endpoint', 'engin', 'enhanc', 'enough', 'ensur', 'enterpris', 'entir', 'entitl', 'env', 'environ', 'error', 'evan', 'evolv', 'exampl', 'exchang', 'exclus', 'exe', 'execut', 'exhaust', 'exist', 'exit', 'expect', 'expens', 'experi', 'experienc', 'explicit', 'export', 'extend', 'extens', 'extern', 'extrem', 'ezyang', 'fa', 'facad', 'facebook', 'fail', 'failur', 'fals', 'familiar', 'fantast', 'fast', 'faster', 'fastest', 'favorit', 'façad', ...

# %%
files
# Out:
# ['../data/svelte_README.md',
#  '../data/tensorflow_README.md',
#  '../data/react_README.md',
#  '../data/vuejs_README.md',
#  '../data/gcc_README.txt',
#  '../data/linux_README.txt',
#  '../data/cpython_README.rst',
#  '../data/pytorch_README.md',
#  '../data/rust_README.md',
#  '../data/cira_README.md']

# %%
len(files)
# Out:
# 10

# %% [markdown]
# ### K-Means cluster

# %%
from sklearn import cluster
import numpy as np

# %%
def keyword_cluster(content:list):
    vectorizer = TfidfVectorizer()
    features = vectorizer.fit_transform(raw_documents=content)
    X = pd.DataFrame(features.toarray(), index=content, columns=vectorizer.get_feature_names_out())
    model = cluster.AffinityPropagation()
    X["predict"] = model.fit_predict(X)
    return X["predict"] 

keyword_cluster(contents)
# Out:
# cybernet enhanc app svelt sveltej github asset banner png svelt dev npm version img shield npm svelt svg npmj packag svelt img shield npm svelt svg licens chat img shield discord label chat logo discord svelt dev chat svelt svelt build applic compil take declar compon convert effici javascript surgic updat dom learn svelt svelt dev discord chatroom svelt dev chat support svelt svelt mit licens sourc project ongo develop fantast volunt support effort backer collect opencollect svelt fund donat collect compens expens svelt develop host cost suffici donat receiv fund support svelt develop roadmap view roadmap svelt dev roadmap develop pull request encourag pick issu github sveltej svelt issu aissue+i aopen+sort aupdat desc instal svelt local bash git clone github sveltej svelt git svelt npm instal yarn instal depend specif packag version packag lock json build svelt build compil modul includ packag bash npm build watch continu rebuild packag npm link doc npmj cli link project local bash npm dev compil written typescript typescriptlang basic javascript type annot pick time editor visual studio code code visualstudio instal plugin syntax highlight code hint run test bash npm filter test aka grep test involv transit bash npm transit svelt dev sourc code svelt dev live site github sveltej site repositori document content content directori built sveltekit kit svelt dev svelt dev access dev site check superus question answer superus licens mit licens                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# div align center img src tensorflow imag logo horizont png div python img shield pypi pyvers tensorflow svg style plastic badg furi tensorflow pypi badg furi tensorflow svg badg furi tensorflow doi zenodo badg doi zenodo svg doi zenodo cii practic bestpractic coreinfrastructur project badg bestpractic coreinfrastructur project openssf scorecard api securityscorecard dev project github tensorflow tensorflow badg api securityscorecard dev project github tensorflow tensorflow fuzz statu oss fuzz build log storag googleapi badg tensorflow svg bug chromium oss fuzz issu list sort proj tensorflow fuzz statu oss fuzz build log storag googleapi badg tensorflow svg bug chromium oss fuzz issu list sort proj tensorflow ossrank shield endpoint url ossrank shield ossrank contributor coven img shield badg contributor coven svg code conduct document document img shield badg api refer blue svg tensorflow api doc tensorflow tensorflow sourc platform machin learn comprehens flexibl ecosystem tool tensorflow resourc tool librari tensorflow resourc librari extens commun tensorflow commun resourc research push art develop easili build deploy power applic tensorflow origin develop research engin googl brain team googl machin intellig organ conduct machin learn deep neural network applic wide varieti domain tensorflow stabl python tensorflow api doc python c++ tensorflow api doc api guarante compat api languag tensorflow api doc releas announc secur updat subscrib tensorflow googl tensorflow forum forum mail list tensorflow commun forum instal tensorflow instal guid tensorflow instal pip packag tensorflow instal pip enabl gpu support tensorflow instal gpu docker contain tensorflow instal docker build sourc tensorflow instal sourc instal current releas includ support cuda enabl gpu card tensorflow instal gpu ubuntu window $ pip instal tensorflow devic directx maco metal support devic plugin tensorflow instal gpu plugin devic cpu packag $ pip instal tensorflow cpu updat tensorflow version add upgrad flag command nightli binari test nightli pypi python pypi nightli nightli cpu pypi python pypi nightli cpu packag pypi tensorflow program $ python python import tensorflow add numpi constant tensorflow numpi tensorflow exampl tensorflow tutori tensorflow tutori contribut guidelin contribut tensorflow review contribut guidelin contribut project adher tensorflow code conduct code conduct particip expect uphold code github issu github tensorflow tensorflow issu track request bug tensorflow forum discuss tensorflow question discuss direct specif question stack overflow stackoverflow question tag tensorflow tensorflow project strive abid accept practic sourc softwar develop patch guidelin follow step patch specif version tensorflow appli fix bug secur vulner clone tensorflow repo switch branch desir tensorflow version branch version appli cherri pick desir resolv code conflict tensorflow test ensur pass build tensorflow instal sourc tensorflow pip packag sourc continu build statu commun support platform configur tensorflow sig build commun build tabl github tensorflow build commun support tensorflow build offici build build type statu artifact linux cpu statu storag googleapi tensorflow kokoro build badg ubuntu svg storag googleapi tensorflow kokoro build badg ubuntu pypi pypi project nightli linux gpu statu storag googleapi tensorflow kokoro build badg ubuntu gpu svg storag googleapi tensorflow kokoro build badg ubuntu gpu pypi pypi project nightli gpu linux xla statu storag googleapi tensorflow kokoro build badg ubuntu xla svg storag googleapi tensorflow kokoro build badg ubuntu xla tba maco statu storag googleapi tensorflow kokoro build badg maco svg storag googleapi tensorflow kokoro build badg maco pypi pypi project nightli window cpu statu storag googleapi tensorflow kokoro build badg window cpu svg storag googleapi tensorflow kokoro build badg window cpu pypi pypi project nightli window gpu statu storag googleapi tensorflow kokoro build badg window gpu s ...
# react reactj middot; github img shield badg mit blue svg github facebook react blob main licens npm version img shield npm react svg style flat npmj packag react circleci statu circleci facebook react svg style shield circleci facebook react pr img shield badg pr brightgreen svg reactj doc contribut pull request react javascript librari build user interfac declar react painless creat interact ui design simpl view applic react effici updat render compon data declar view code predict simpler understand easier debug compon base build encapsul compon manag compos complex ui compon logic written javascript templat easili pass rich data app dom learn write assumpt rest technolog stack develop featur react rewrit exist code react render server node power mobil app react nativ reactn dev learn react project reactj doc start instal react design gradual adopt start react onlin playground reactj doc start onlin playground tast react add react reactj doc add react script tag minut creat react app reactj doc creat react app power javascript toolchain react script tag cdn reactj doc cdn link react packag npm npmj packag react document react document reactj check start reactj doc start quick overview document divid section tutori reactj tutori tutori main concept reactj doc advanc guid reactj doc jsx depth api refer reactj doc react api support reactj commun support contribut guid reactj doc contribut improv send pull request repositori github reactj reactj exampl exampl reactj start jsx import createroot react dom client ; function hellomessag return div div ; const root createroot document getelementbyid contain ; root render hellomessag taylor ; render taylor contain notic syntax; jsx reactj doc introduc jsx jsx requir react code readabl write feel write react script tag read reactj doc add react option react jsx integr jsx; recommend javascript toolchain reactj doc creat react app handl automat contribut main purpos repositori continu evolv react core faster easier develop react github grate commun contribut bugfix improv read learn improv react code conduct code fb codeofconduct facebook code conduct expect project particip adher read code fb codeofconduct understand action toler contribut guid reactj doc contribut read contribut guid reactj doc contribut learn develop process propos bugfix improv build react issu feet wet familiar contribut process list issu github facebook react label issu bug limit scope start licens react mit licens licens                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# align center href vuej target blank rel noopen noreferr img src vuej imag logo png alt vue logo align center href circleci vuej vue tree dev img src img shield circleci project github vuej vue dev svg sanit true alt build statu href codecov github vuej vue branch dev img src img shield codecov github vuej vue dev svg sanit true alt coverag statu href npmchart compar vue minim true img src img shield npm vue svg sanit true alt download href npmj packag vue img src img shield npm vue svg sanit true alt version href npmj packag vue img src img shield npm vue svg sanit true alt licens href chat vuej img src img shield badg chat discord da svg sanit true alt chat repo vue repositori vue repo vue vuej core github vuej core sponsor vue js mit licens sourc project ongo develop support awesom backer github vuej core blob main backer sponsor vue develop vuej sponsor align center align center special sponsor align center target blank href github appwrit appwrit img alt special sponsor appwrit src sponsor vuej imag appwrit svg align center target blank href vuej sponsor img alt sponsor src sponsor vuej sponsor svg introduct vue pronounc view progress framework build user interfac design ground increment adopt easili scale librari framework depend consist approach core librari focus view layer ecosystem support librari help tackl complex singl applic browser compat vue js support browser compliant kangax github compat tabl support ecosystem project statu descript vue router vue router statu vue router packag singl applic rout vuex vuex statu vuex packag scale manag vue cli vue cli statu vue cli packag project scaffold vue loader vue loader statu vue loader packag singl file compon vue file loader webpack vue server render vue server render statu vue server render packag server render support vue class compon vue class compon statu vue class compon packag typescript decor class base api vue rx vue rx statu vue rx packag rxj integr vue devtool vue devtool statu vue devtool packag browser devtool extens vue router github vuej vue router vuex github vuej vuex vue cli github vuej vue cli vue loader github vuej vue loader vue server render github vuej vue tree dev packag vue server render vue class compon github vuej vue class compon vue rx github vuej vue rx vue devtool github vuej vue devtool vue router statu img shield npm vue router svg vuex statu img shield npm vuex svg vue cli statu img shield npm vue cli svg vue loader statu img shield npm vue loader svg vue server render statu img shield npm vue server render svg vue class compon statu img shield npm vue class compon svg vue rx statu img shield npm vue rx svg vue devtool statu img shield chrome store nhdogjmejiglipccpnnnanhbledajbpd svg vue router packag npmj packag vue router vuex packag npmj packag vuex vue cli packag npmj packag vue cli vue loader packag npmj packag vue loader vue server render packag npmj packag vue server render vue class compon packag npmj packag vue class compon vue rx packag npmj packag vue rx vue devtool packag chrome googl webstor vuej devtool nhdogjmejiglipccpnnnanhbledajbpd document check live exampl vuej exampl doc visit vuej vuej question question support offici forum forum vuej commun chat chat vuej issu list repo exclus bug report featur request issu read issu report checklist github vuej vue blob dev github contribut issu report guidelin issu issu conform guidelin close changelog detail releas document releas note github vuej vue releas stay touch twitter twitter vuej blog medium vue job board vuejob vuej contribut read contribut guid github vuej vue blob dev github contribut pull request vue project compon tool add pull request curat list github vuej awesom vue peopl contribut vue href github vuej vue graph contributor img src opencollect vuej contributor svg licens mit opensourc licens mit copyright yuxi evan                                                                                                                                                   ...
# directori gnu compil collect gcc gnu compil collect softwar file name start copi copi permiss manual runtim librari terms; individu sourc file detail directori instal copi instal plain sourc gcc doc instal texi instal includ detail includ gcc sourc file gcc instal file gcc doc gcc texi file includ usag port onlin readabl version manual file gcc doc gcc info gcc gnu bug report bug copyright gcc sourc file list rang notat indic rang inclus copyright list individu                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# linux kernel guid kernel develop user guid render format pdf read document admin guid readm rst build document htmldoc pdfdoc format document read onlin kernel doc file document subdirectori restructur markup notat read document process rst file requir build run kernel result upgrad kernel                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# python version alpha imag github python cpython workflow test badg svg alt cpython build statu github action target github python cpython action imag dev azur python cpython api build statu azur pipelin branchnam main alt cpython build statu azur devop target dev azur python cpython build definitionid branchnam main imag img shield badg discours chat brightgreen svg alt python discours chat target discuss python copyright © python softwar foundat right file copyright content python sourc code github python cpython issu tracker github python cpython issu document doc python develop guid devguid python contribut cpython complet instruct contribut cpython develop develop guid develop guid devguid python python instal python kit python python python python build instruct unix linux bsd maco cygwin configur sudo instal instal python python pass option configur script; configur maco insensit file system cygwin execut call python exe ; python build complet python instal requir addit parti librari depend build platform configur option standard librari modul buildabl useabl platform refer instal depend devguid python start setup build build depend develop guid current detail depend linux distribut maco maco addit configur build option maco framework univers build refer mac readm rst github python cpython blob main mac readm rst window pcbuild readm txt github python cpython blob main pcbuild readm txt creat subdirectori invok configur mkdir debug debug configur pydebug fail built level directori clean level optim build python configur enabl optim set default target enabl profil guid optim pgo auto enabl link time optim lto platform detail section profil guid optim ^^^^^^^^^^^^^^^^^^^^^^^^^^^ pgo take advantag version gcc clang compil configur enabl optim manual run profil opt configur flag optim build process perform step entir python directori clean temporari file previou compil instrument version interpret built suitabl compil flag flavor note intermediari step binari step real life workload profil instruct embed instrument interpret built makefil train workload profil interpret execut note output stdout stderr step suppress final step build actual interpret collect instrument result python binari optimized; suitabl distribut product instal link time optim ^^^^^^^^^^^^^^^^^^^^^^ enabl configur lto flag lto take advantag abil compil toolchain optim arbitrari file boundari build final execut share librari addit perform gain comprehens overview python doc python whatsnew document detail chang log read misc news github python cpython tree main misc news account glean commit histori github python cpython commit main instal multipl version python entitl instal multipl version document document python doc python onlin updat daili download format faster access document download pdf restructuredtext formats; version document author translat peopl special format requir build python document refer doc readm rst github python cpython blob main doc readm rst convert python incompat releas python program written python fail python port code python python port howto doc python howto pyport test interpret type level directori set produc output ignor messag skip test option featur import messag print fail traceback core dump produc wrong default test prevent overus resourc disk space memori enabl test testal test fail fail verbos mode os gdb fail testopt os gdb failur persist appear python environ file bug report github python cpython issu includ relev output command issu run write test devguid python test write test run test instal multipl version unix mac system intend instal multipl version python instal prefix prefix argument configur script care primari python execut overwritten instal version file directori instal altinstal major minor version live instal creat $ prefix bin python refer $ prefix bin python intend instal multipl version prefix decid version primari version instal version instal instal version altinstal instal python primari vers ...
# pytorch logo github pytorch pytorch blob main doc sourc static img pytorch logo dark png pytorch python packag level featur tensor comput numpi strong gpu acceler deep neural network built tape base autograd reus favorit python packag numpi scipi cython extend pytorch trunk health continu integr signal hud pytorch hud pytorch pytorch pytorch main toc pytorch pytorch gpu readi tensor librari gpu readi tensor librari dynam neural network tape base autograd dynam neural network tape base autograd python python imper experi imper experi fast lean fast lean extens pain extens pain instal instal binari binari nvidia jetson platform nvidia jetson platform sourc sourc prerequisit prerequisit instal depend instal depend pytorch sourc pytorch sourc instal pytorch instal pytorch adjust build option option adjust build option option docker imag docker imag pre built imag pre built imag build imag build imag build document build document previou version previou version start start resourc resourc commun commun releas contribut releas contribut team team licens tocstop pytorch granular level pytorch librari consist compon compon descript torch pytorch doc stabl torch tensor librari numpi strong gpu support torch autograd pytorch doc stabl autograd tape base automat differenti librari support differenti tensor oper torch torch jit pytorch doc stabl jit compil stack torchscript creat serializ optimiz model pytorch code torch nn pytorch doc stabl nn neural network librari deepli integr autograd design maximum flexibl torch multiprocess pytorch doc stabl multiprocess python multiprocess magic memori share torch tensor process data load hogwild train torch util pytorch doc stabl data dataload util function conveni pytorch replac numpi power gpu deep learn platform maximum flexibl speed elabor gpu readi tensor librari numpi tensor ndarray tensor illustr doc sourc static img tensor illustr png pytorch tensor live cpu gpu acceler comput huge provid wide varieti tensor routin acceler fit scientif comput slice index mathemat oper linear algebra reduct fast dynam neural network tape base autograd pytorch uniqu build neural network replay tape record framework tensorflow theano caff cntk static view build neural network reus structur chang network behav start scratch pytorch techniqu call revers mode auto differenti chang network behav arbitrarili lag overhead inspir paper topic current torch autograd github twitter torch autograd autograd github hip autograd chainer chainer techniqu uniqu pytorch fastest implement speed flexibl crazi dynam graph github pytorch pytorch blob main doc sourc static img dynam graph gif python pytorch python bind monolith c++ framework built deepli integr python natur numpi numpi scipi scipi scikit learn scikit learn write neural network layer python favorit librari packag cython cython numba numba pydata goal reinvent wheel imper experi pytorch design intuit linear easi execut code execut asynchron view drop debugg receiv error messag stack trace understand straightforward stack trace code defin hope spend hour debug code bad stack trace asynchron opaqu execut engin fast lean pytorch minim framework overhead integr acceler librari intel mkl softwar intel mkl nvidia cudnn develop nvidia cudnn nccl develop nvidia nccl maxim speed core cpu gpu tensor neural network backend matur test pytorch fast neural network memori usag pytorch extrem effici compar torch altern written custom memori alloc gpu deep learn model maxim memori effici enabl train bigger deep learn model extens pain write neural network modul interfac pytorch tensor api design straightforward minim abstract write neural network layer python torch api favorit numpi base librari scipi pytorch tutori advanc numpi extens tutori write layer c++ provid conveni extens api effici minim boilerpl wrapper code written tutori pytorch tutori advanc cpp extens github pytorch extens cpp instal binari command instal binari conda pip wheel pytorch start local pytorch start local  ...
# rust program languag rust commun img shield badg rust commun brightgreen style plastic logo rust rust lang commun main sourc code repositori rust compil standard librari document rust rust lang note readm user contributor contribut compil read contribut contribut quick start read instal book instal doc rust lang book instal book doc rust lang book instal sourc rust build python script call build compil manag bootstrap process live root project file name config toml determin configur set build list option config toml command unix system format subcommand flag document exampl assum run altern unix python command subcommand flag window command prompt file configur python subcommand flag python python subcommand flag run flag read rustc dev guid rustcguidebuild gettingstart rustc dev guid rust lang start rustcguidebuild rustc dev guid rust lang build build depend instal depend python git compil build host enough; cross compil addit compil curl window pkg config compil linux target linux libiconv includ glibc debian base distro build cargo openssl libssl dev openssl devel unix distro build llvm sourc addit tool g++ clang++ msvc version list llvm document llvm doc gettingstart host toolchain compil standard librari ninja gnu ninja recommend window cmake libstdc++ static requir linux distribut fedora ubuntu tier tier host tool platform choos download llvm set llvm download llvm true llvm instal llvm config path rustc dev guid info sysllvm sysllvm rustc dev guid rust lang build target pre built llvm build unix build step clone sourc git git clone github rust lang rust git rust sourc github rust lang rust configur build set configur plan instal creat instal recommend set prefix instal directori configur set instal prefix path build instal build instal complet instal program $prefix bin rustc rust compil rustdoc api document tool default includ cargo rust packag manag disabl behavior pass set build extend fals configur cargo github rust lang cargo configur project configur script makefil invok configur recommend programat gener config toml recommend support break unnecessarili configur sudo instal configur gener config toml normal invoc build window window winget instal depend run termin powershel winget instal python python winget instal kitwar cmake winget instal git git edit path variabl add program file cmake bin guid edit path java en download path java document winget github winget cli promin abi window nativ msvc abi visual studio gnu abi gcc toolchain version rust depend c++ librari interoper msvc build rust interop softwar produc visual studio gnu build interop gnu softwar built mingw msi toolchain mingw msi msi easili build rust window msi msi download msi instal msi instal mingw bat mingw bat msi instal directori msi depend bit bit rust version msi msi cmd mingw msi cmd mingw command termin instal requir tool updat packag mirror fresh instal msi pacman pacman mirror instal build tool rust build bit compil replac git python cmake instal path remov list note python cmake ninja packag msi subsystem build histor fail packag pacman git diffutil tar mingw python mingw cmake mingw gcc mingw ninja navig rust sourc code clone build python setup user python build python instal msvc msvc build rust addit requir instal visual studio rustc linker simplest visual studio check c++ build tool window sdk workload visual studio visualstudio download instal cmake care c++ cmake tool window includ individu compon depend instal build compil cmd exe python setup user python build build rust version visual studio version instal build understand forc rustbuild version manual call vcvar file run bootstrap batch program file visual studio commun auxiliari build vcvar bat python build abi specif abi environ gnu abi powershel explicit build tripl window build tripl gnu abi gcc pc window gnu pc window gnu msvc abi pc window msvc pc window msvc build tripl build tripl invok command creat config toml file build unix build unix pass set build build tripl co ...
# cira cira algorithm trade easi façad librari refactor guru design pattern facad simpler interact alpaca trade api alpaca market cira pip pypi project cira star cira extern content duckduckgo iu pinimg fb fb cfea fcfeceeb fa ced llama draw draw art jpg nofb github star img shield github star axelgard cira style social github fork img shield github fork axelgard cira style social tweet img shield twitter url shield svg style social twitter axel gard github img shield github axelgard cira style plastic pypi img shield pypi cira pypi python version img shield pypi pyvers cira pypi download img shield pypi cira cira spell word babi alpaca cria en wikipedia wiki cria simpl lib perfect fit axel gard github axelgard main develop cira start start fast cira boilerpl github cira cira boilerpl cira checkout tutori github axelgard cira wiki tutori instal instal pip pypi project cira bash pip instal cira usag alpaca trade api api key gener key alpaca market app alpaca market signup play paper trade recommend beginn recommend json file cira path set variabl environ variabl wiki github axelgard cira wiki store alpaca api key diffrent recommend store file upload file public repositori key json json apca api key pub key apca api secret key privat key start lib python import cira cira alpaca key file mypath key json stock cira stock tsla stock stock sell class cira python portfolio cira portfolio method portfolio exchang cira exchang method exchang stock cira stock tsla class stock simpl algorithm coupl line run super simpl algorithm python import cira import random import time cira alpaca key file mypath key json portfolio cira portfolio exchang cira exchang qti choos stock handl session true exchang stock random choic exchang stock qti stock stock random choic portfolio own stock qti stock sell time sleep min timer exampl wiki exampl github axelgard cira wiki exampl wiki tutori github axelgard cira wiki tutori checkout news github axelgard cira discuss categori news wiki github axelgard cira wiki tutori github axelgard cira wiki tutori store alpaca api key github axelgard cira wiki store alpaca api key exampl cira github axelgard cira wiki exampl discuss github axelgard cira discuss cira github cira wiki github axelgard cira wiki doc check wiki github axelgard cira wiki build fund trader cira github axelgard cira wiki exampl simpl fund version compat fork cira cira classic github axelgard cira classic cira classic pypi pip pypi project cira classic bug plz issu solv pull request question question cira share built cira talk cira checkout discuss github axelgard cira discuss issu fit histori cira alpaca trade api build quantit paper trader project github axelgard paper trader alomst realiz alomst build librari alpaca api real librari start quantit paper trade develop develop cira feel pull request issu instal cira dev req bash git clone git github axelgard cira git cira git checkout develop bash python venv env sourc env bin activ pip instal test pytest ensur cira dir key key test mind asset portfolio sold bash touch test key json pytest code style follow pep pep standard notat librari intuit easi licens project licens mit licens licens licens txt file detail acknowledg alpaca api alpaca market paper trader github axelgard paper trader cira classic github axelgard cira classic                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# Name: predict, dtype: int64
